# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path_v = '../data/Vaccination_Coverage_among_Adults__18__Years__20240107.csv'
vaccination_data = pd.read_csv(file_path_v)
vaccination_data.head()
# Out:
#         Vaccine      Geography Type State Name  FIPS  State FIPS  Survey Year  \
# 0            Td  States/Local Areas    Alabama     1         1.0         2019
# 1            Td  States/Local Areas    Alabama     1         1.0         2013
# 2            Td  States/Local Areas    Alabama     1         1.0         2019
# 3  Pneumococcal  States/Local Areas    Alabama     1         1.0         2020
# 4  Pneumococcal  States/Local Areas    Alabama     1         1.0         2021
#
#   Dimension Type            Dimension Estimate (%)    95% CI (%)  Sample Size
# 0          18-64    Other or Multiple         67.7  59.2 to 76.1        209.0
# 1          18-64  White, Non-Hispanic         54.1  51.9 to 56.3       3819.0
# 2          18-64             Hispanic         52.3  37.4 to 67.1         73.0
# 3    65 or Older    Other or Multiple         57.4  37.4 to 77.4         51.0
# 4    65 or Older    Other or Multiple         73.5  56.8 to 90.3         48.0

# %%
vaccination_data.describe()
# Out:
#                FIPS    State FIPS   Survey Year    Sample Size
# count  52557.000000  13142.000000  52557.000000   18234.000000
# mean   19909.640600     29.273246   2018.129212    2837.856861
# std    18944.205763     15.768186      3.130467   12421.962471
# min        1.000000      1.000000   2008.000000       0.000000
# 25%       56.000000     17.000000   2018.000000      97.000000
# 50%    18093.000000     29.000000   2019.000000     601.500000
# 75%    37113.000000     44.000000   2020.000000    2215.000000
# max    56045.000000     56.000000   2022.000000  406086.000000

# %%
vaccination_data["Survey Year"].max()
# Out:
# 2022

# %%
vaccination_data['Estimate (%)'] = pd.to_numeric(vaccination_data['Estimate (%)'], errors='coerce')

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Vaccine', y='Estimate (%)', data=vaccination_data)
plt.title('Vaccination Rates by Type')
plt.xlabel('Vaccine Type')
plt.ylabel('Vaccination Rate (%)')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(14, 7))
sns.lineplot(x='Survey Year', y='Estimate (%)', hue='Vaccine', data=vaccination_data, errorbar=None)
plt.title('Vaccination Rates Over Time')
plt.xlabel('Survey Year')
plt.ylabel('Vaccination Rate (%)')
plt.legend(title='Vaccine', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
custom_palette = {
    'Td': '#52427b',  # Example hex code color for Vaccine1
    'Pneumococcal': '#9173b9',
    'Tdap': '#ad95d5',
    'Zoster (Shingles)': '#dfc0ff',# Example hex code color for Vaccine2
    # Add more vaccines and their corresponding colors as needed
}

# Create the lineplot with the custom palette
plt.figure(figsize=(14, 7))
sns.lineplot(x='Survey Year', y='Estimate (%)', hue='Vaccine', data=vaccination_data,
             palette=custom_palette, linewidth=2.5, errorbar=None)

plt.title('Vaccination Rates Over Time')
plt.xlabel('Survey Year')
plt.ylabel('Vaccination Rate (%)')
plt.legend(title='Vaccine', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Estimate (%)', y='Geography', data=vaccination_data, ci=None)
plt.title('Average Vaccination Rates by Location')
plt.xlabel('Average Vaccination Rate (%)')
plt.ylabel('Geography')
plt.show()
